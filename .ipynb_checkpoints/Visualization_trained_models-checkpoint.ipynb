# %%
import numpy as np
import json
import os
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from keras.utils import plot_model
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.models import Model, load_model, model_from_json
from tensorflow.keras.preprocessing import image
from sklearn.externals import joblib
import matplotlib.pyplot as plt
import cv2
import pickle
import seaborn as sns
import pandas as pd

# %%
def get_models_paths(folder):
    files = os.listdir(folder)
    files.sort()
    files = ['{}/{}'.format(folder,file) for file in files if not file.startswith('.')]
    return files

# %%
def prepare(filepath):
    IMG_SIZE = 71  # 50 in txt-based
    img_array = cv2.imread(filepath)
    img_array = img_array / 255
    new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
    return new_array.reshape(-1, IMG_SIZE, IMG_SIZE, 3)

# %%
models_json = get_models_paths('trained_model_files/logos/JSON')
print('\n'.join('{}: {}'.format(*k) for k in enumerate(models_json)))
# Out:
# 0: trained_model_files/logos/JSON/TMCL_v46_3WAYS_10EP_CL_82.19_.json
# 1: trained_model_files/logos/JSON/TMCL_v46_Xception_11EP_81.8_.json
# 2: trained_model_files/logos/JSON/TMCL_v47_Xception_11EP_82.75_.json

# %%
models_h5 = get_models_paths('trained_model_files/logos/H5')
# print('\n'.join('{}: {}'.format(*k) for k in enumerate(models_json)))

# %%
index_to_model = 2
json_file = open(models_json[index_to_model], "r")
loaded_model_json = json_file.read()
json_file.close()
# loaded_model = model_from_json(loaded_model_json, custom_objects={'BatchNormalizationV1': BatchNormalizationV1()})
loaded_model_CI = model_from_json(loaded_model_json)
loaded_model_CI.load_weights(models_h5[index_to_model])
loaded_model_CI.compile(
    loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"]
)

# %%
json_file = open(models_json[32], "r")
loaded_model_json = json_file.read()
json_file.close()
loaded_model_CI = model_from_json(loaded_model_json)
loaded_model_CI.load_weights(models_h5[32])
loaded_model_CI.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
json_file = open(models_json[25], "r")
loaded_model_json = json_file.read()
json_file.close()
loaded_model_DI = model_from_json(loaded_model_json)
loaded_model_DI.load_weights(models_h5[25])
loaded_model_DI.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
plot_model(activation_model_CI, show_shapes=True, show_layer_names=True, to_file='model.png')

# %% [markdown]
# #### Dirty imgs for vizualization

# %%
filename = "trained_data/X_4_di_pa_3ch_test.sav"
X_DI = joblib.load(filename)

# %%
filename = "trained_data/y_4_di_pa_3ch_test.sav"
Y_DI = joblib.load(filename)

# %%
filename = "trained_data/Z_4_di_pa_3ch_test.sav"
Z_DI = joblib.load(filename)

# %% [markdown]
# #### Clean imgs for vizualization

# %%
filename = "trained_data/X_CI_pa_3ch_test.sav"
X_CI = joblib.load(filename)

# %%
filename = "trained_data/Y_CI_pa_3ch_test.sav"
Y_CI = joblib.load(filename)

# %%
filename = "trained_data/Z_CI_pa_3ch_test.sav"
Z_CI = joblib.load(filename)

# %%
filename = "trained_data/to_test/X_CLP_SYMBOLS_test_30x30.sav"
X = joblib.load(filename)

# %%
filename = "trained_data/to_test/Y_CLP_SYMBOLS_test_30x30.sav"
Y = joblib.load(filename)

# %%
filename = "trained_data/to_test/Z_CLP_SYMBOLS_test_30x30.sav"
Z = joblib.load(filename)

# %%
loaded_model_CI.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# xception (Model)             (None, 3, 3, 2048)        20861480
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               4718848
# _________________________________________________________________
# activation (Activation)      (None, 256)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 40)                10280
# _________________________________________________________________
# activation_1 (Activation)    (None, 40)                0
# ...
# Total params: 25,590,608
# ...

# %%
def split(model, start, end):
    confs = model.get_config()
    kept_layers = set()
    for i, l in enumerate(confs['layers']):
        if i == 0:
            confs['layers'][0]['config']['batch_input_shape'] = model.layers[start].input_shape
            if i != start:
                confs['layers'][0]['name'] += str(random.randint(0, 100000000)) # rename the input layer to avoid conflicts on merge
                confs['layers'][0]['config']['name'] = confs['layers'][0]['name']
        elif i < start or i > end:
            continue
        kept_layers.add(l['name'])
    # filter layers
    layers = [l for l in confs['layers'] if l['name'] in kept_layers]
    layers[1]['inbound_nodes'][0][0][0] = layers[0]['name']
    # set conf
    confs['layers'] = layers
    confs['input_layers'][0][0] = layers[0]['name']
    confs['output_layers'][0][0] = layers[-1]['name']
    # create new model
    submodel = Model.from_config(confs)
    for l in submodel.layers:
        orig_l = model.get_layer(l.name)
        if orig_l is not None:
            l.set_weights(orig_l.get_weights())
    return submodel

# %%
submodel = split(loaded_model_CI.layers[0], 0, 70)

# %%
print(submodel.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 71, 71, 3)    0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 35, 35, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 35, 35, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 35, 35, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 33, 33, 64)   18432       block1_conv1_act[0][0]
# ...

# %%
activation_model_CI = Model(inputs=submodel.input, 
                         outputs=submodel.layers[32].output)

# %%
activation_model_CI.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 71, 71, 3)    0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 35, 35, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 35, 35, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 35, 35, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 33, 33, 64)   18432       block1_conv1_act[0][0]
# ...

# %%
print(activation_model_CI.layers[1].get_weights())

# %%
img_path = "/home/apofeo/Downloads/new_images/IMG_20171022_182919.jpg"
activation_CI = activation_model_CI.predict(prepare(img_path))
print(activation_CI.shape)
# Out:
# (1, 5, 5, 728)

# %%
plt.matshow(activation_CI[0, :, :, 0])

# %%
w=10
h=10
fig=plt.figure(figsize=(7, 9))
columns = 4
rows = 5
for i in range(1, columns*rows +1):
#     img = np.random.randint(10, size=(h,w))
    fig.add_subplot(rows, columns, i)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(activation_CI[0, :, :, 0 + i])
plt.show()

# %%
activation_model_CI = Model(inputs=loaded_model_CI.input, 
                         outputs=loaded_model_CI.layers[6].output)

# %%
activation_model_CI.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# xception_input (InputLayer)  (None, 71, 71, 3)         0
# _________________________________________________________________
# xception (Model)             (None, 3, 3, 2048)        20861480
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               4718848
# _________________________________________________________________
# activation (Activation)      (None, 256)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 40)                10280
# ...

# %%
img_path = Z[0]
activation_CI = activation_model_CI.predict(prepare(img_path))
print(activation_CI.shape)
# Out:
# (1, 9, 9, 256)

# %%
plt.matshow(activation_CI[0, :, :, 0])

# %%
w=10
h=10
fig=plt.figure(figsize=(7, 9))
columns = 4
rows = 5
for i in range(1, columns*rows +1):
#     img = np.random.randint(10, size=(h,w))
    fig.add_subplot(rows, columns, i)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(activation_CI[0, :, :, 0 + i])
plt.show()

# %%
activation_model_CI = Model(inputs=loaded_model_CI.input, 
                         outputs=loaded_model_CI.layers[8].output)

# %%
activation_CI = activation_model_CI.predict(prepare(Z_CI[0]))
print(activation_CI.shape)
# Out:
# (1, 21, 21, 512)

# %%
plt.matshow(activation_CI[0, :, :, 0])

# %%
w=10
h=10
fig=plt.figure(figsize=(7, 9))
columns = 4
rows = 5
for i in range(1, columns*rows +1):
#     img = np.random.randint(10, size=(h,w))
    fig.add_subplot(rows, columns, i)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(activation_CI[0, :, :, 0 + i])
plt.show()

# %%
loaded_model_DI.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_12 (Conv2D)           (None, 98, 98, 64)        640
# _________________________________________________________________
# activation_15 (Activation)   (None, 98, 98, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 96, 96, 128)       73856
# _________________________________________________________________
# activation_16 (Activation)   (None, 96, 96, 128)       0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 48, 48, 128)       0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 48, 48, 128)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 46, 46, 256)       295168
# ...

# %%
activation_model_DI = Model(inputs=loaded_model_DI.input, 
                         outputs=loaded_model_DI.layers[0].output)

# %%
activation_model_DI.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_12_input (InputLayer) (None, 100, 100, 1)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 98, 98, 64)        640
# ...
# Total params: 640
# Trainable params: 640
# Non-trainable params: 0
# _________________________________________________________________

# %%
activation_DI = activation_model_DI.predict(prepare(Z_DI[0]))
print(activation_DI.shape)
# Out:
# (1, 98, 98, 64)

# %%
plt.matshow(activation_DI[0, :, :, 0])

# %%
w=10
h=10
fig=plt.figure(figsize=(7, 9))
columns = 4
rows = 5
for i in range(1, columns*rows +1):
#     img = np.random.randint(10, size=(h,w))
    fig.add_subplot(rows, columns, i)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(activation_DI[0, :, :, 0 + i])
plt.show()

# %%
activation_model_DI = Model(inputs=loaded_model_DI.input, 
                         outputs=loaded_model_DI.layers[2].output)

# %%
activation_model_DI.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_12_input (InputLayer) (None, 100, 100, 1)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 98, 98, 64)        640
# _________________________________________________________________
# activation_15 (Activation)   (None, 98, 98, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 96, 96, 128)       73856
# ...
# Total params: 74,496
# Trainable params: 74,496
# Non-trainable params: 0
# _________________________________________________________________

# %%
activation_DI = activation_model_DI.predict(prepare(Z_DI[0]))
print(activation_DI.shape)
# Out:
# (1, 96, 96, 128)

# %%
plt.matshow(activation_DI[0, :, :, 0])

# %%
w=10
h=10
fig=plt.figure(figsize=(7, 9))
columns = 4
rows = 5
for i in range(1, columns*rows +1):
#     img = np.random.randint(10, size=(h,w))
    fig.add_subplot(rows, columns, i)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(activation_DI[0, :, :, 0 + i])
plt.show()

# %%
activation_model_DI = Model(inputs=loaded_model_DI.input, 
                         outputs=loaded_model_DI.layers[6].output)

# %%
activation_DI = activation_model_DI.predict(prepare(Z_DI[0]))
print(activation_DI.shape)
# Out:
# (1, 46, 46, 256)

# %%
plt.matshow(activation_DI[0, :, :, 0])

# %%
w=10
h=10
fig=plt.figure(figsize=(7, 9))
columns = 4
rows = 5
for i in range(1, columns*rows +1):
#     img = np.random.randint(10, size=(h,w))
    fig.add_subplot(rows, columns, i)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(activation_DI[0, :, :, 0 + i])
plt.show()

# %%
activation_model_DI = Model(inputs=loaded_model_DI.input, 
                         outputs=loaded_model_DI.layers[8].output)

# %%
activation_DI = activation_model_DI.predict(prepare(Z_DI[0]))
print(activation_DI.shape)
# Out:
# (1, 44, 44, 256)

# %%
plt.matshow(activation_DI[0, :, :, 0])

# %%
w=10
h=10
fig=plt.figure(figsize=(7, 9))
columns = 4
rows = 5
for i in range(1, columns*rows +1):
#     img = np.random.randint(10, size=(h,w))
    fig.add_subplot(rows, columns, i)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(activation_DI[0, :, :, 0 + i])
plt.show()
