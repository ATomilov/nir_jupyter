# %%
import matplotlib.image as mpimg
import os
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import pandas as pd
from PIL import Image
from PIL import ImageFilter
from PIL import ImageOps
from IPython.display import HTML, display
from pylab import *
# !pip install tabulate
import tabulate
import cv2

np.set_printoptions(threshold=np.nan)

# pd.set_option('display.expand_frame_repr', False)
# pd.options.display.max_rows = 10000
# display.max_columns = 1000000
# pd.display.max_columns = 1000000
# First, load the image
# dir_path = os.path.dirname(os.path.realpath(__file__))
# filename = "220px-Batian_Nelion_and_pt_Slade_in_the_foreground_Mt_Kenya.JPG"
filename = "4.bmp"
image = tf.image.decode_jpeg(tf.read_file(filename), channels=3) 
grey_image = tf.image.rgb_to_grayscale(image)
grey_image = grey_image.get_shape()
# np.array(np.array_str(grey_image), dtype=float)
# np.array_str(grey_image)
# grey_image = tf.image.rgb_to_grayscale(filename)
# Load the image
# image = mpimg.imread(filename)


# image = Image.open(filename).convert("L")
# arr = np.asarray(image)
# plt.imshow(arr, cmap='gray')
# plt.show()

# plt.imshow(image, clim=(0.064, 0.068))
# mod_img = ndimage.median_filter(img, 20)
# plt.imshow(mod_img)

# sess = tf.InteractiveSession()
# print(sess.run(grey_image))
# Print out its shape
print(image)
print(grey_image)
# print(image)
# plt.imshow(grey_image)
# plt.imshow(sess.run(grey_image))
# plt.imshow(np.array(grey_image, dtype=float))
# plt.imshow(grey_image)
# plt.imshow(image)
# plt.show()

# img = cv2.imread(filename,0)
# hist = cv2.calcHist([img],[0],None,[256],[0,256])
# hist,bins = np.histogram(img.ravel(),256,[0,256])

# plt.imshow(grey_image, clim=(0.064, 0.068))
# mod_img = ndimage.median_filter(grey_image, 20)
# plt.imshow(mod_img)

iimg = Image.open(filename).convert('LA')
image = Image.open(filename).convert('LA')
image.save('new_image.png')
# iimg = Image.open(filename)
# iimg = ImageOps.autocontrast(i, cutoff=1, ignore=None)
# iimg = ImageOps.autocontrast(i, cutoff=10, ignore=None)
# iimg = ImageOps.invert(i)
# iimg = ImageOps.posterize(i,5)
# iimg = ImageOps.solarize(i, 100)
iar = np.asarray(iimg)
# for a in range (1,iar.size):
#   iar[a].T
# iar = iar.T
# print(iar.size)

# for a in range (1,8):
#   i = Image.open(filename)
#   i = ImageOps.posterize(i,a)
#   plt.imshow(i)
#   plt.show()

# # read image to array
# im = array(i.convert('L'))

# # create a new figure
# figure()
# # don't use colors
# gray()
# # show contours with origin upper left corner
# # contour(im, origin='image')
# axis('equal')
# # axis('off')

# figure()
# hist(im.flatten(),128)
# show()

# img = cv2.imread(filename,0)
# plt.hist(img.ravel(),256,[0,256]); plt.show()

img = cv2.imread('new_image.png')
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

plt.imshow(iimg)
plt.show()
print(iar)

# display(HTML(tabulate.tabulate(iar, tablefmt='html')))
# Out:
# ...
# Tensor("DecodeJpeg_3:0", shape=(?, ?, 3), dtype=uint8)
# (?, ?, 1)
# [[[ 91 255]
#   [ 92 255]
#   [ 91 255]
#   [ 92 255]
#   [ 91 255]
#   [ 92 255]
#   [ 91 255]
#   [ 90 255]
#   [ 90 255]
#   [ 89 255]
#   [ 89 255]
#   [ 90 255]
#   [ 92 255]
#   [ 93 255]
#   [ 95 255]
#   [ 95 255]
#   [ 94 255]
#   [ 94 255]
#   [ 94 255]
#   [ 93 255]
#   [ 92 255]
#   [ 93 255]
#   [ 91 255]
#   [ 92 255]
#   [ 91 255]
#   [ 92 255]
#   [ 93 255]
#   [ 92 255]
#   [ 93 255]
#   [ 92 255]
#   [ 92 255]
#   [ 92 255]
#   [ 92 255]
#   [ 93 255]
#   [ 93 255]
#   [ 92 255]
#   [ 92 255]
#   [ 91 255]
#   [ 93 255]
#   [ 94 255]
#   [ 93 255]
#   [ 94 255]
#   [ 92 255]
#   [ 92 255]
#   [ 92 255]
#   [ 90 255]
#   [ 90 255]
#   [ 91 255]
#   [ 90 255]
#   [ 91 255]
#   [ 90 255]
#   [ 90 255]
#   [ 90 255]
#   [ 89 255]
#   [ 91 255]
#   [ 92 255]
#   [ 92 255]
#   [ 93 255]
#   [ 92 255]
#   [ 93 255]
#   [ 91 255]
#   [ 91 255]
#   [ 88 255]
#   [ 90 255]
#   [ 92 255]
#   [ 92 255]
# ...
