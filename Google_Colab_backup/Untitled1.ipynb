# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from urllib.request import urlopen

image = tf.image.decode_jpeg(tf.read_file("220px-Batian_Nelion_and_pt_Slade_in_the_foreground_Mt_Kenya.JPG"), channels=3) 
grey_image = tf.image.rgb_to_grayscale(image) 
##print(grey_image_2.shape) 
##Image.fromarray(np.asarray(image)).show() 
##plt.imshow(grey_image) 
##plt.show()
# f = open('test.txt', 'w')
sess = tf.InteractiveSession() 
# plt.imshow(grey_image) 
# plt.show() 
# f.write(np.array_str(sess.run(grey_image)))
# sess.close()
# f.close()

# # Build a graph.
# a = tf.constant(5.0)
# b = tf.constant(6.0)
# c = a * b

# # Launch the graph in a session.
# sess = tf.Session()

# # Evaluate the tensor `c`.
# print(sess.run(c))

# image = urllib.request.urlopen('data:image/jpeg;base64,...')
# sess = tf.Session()
# pool3_features = sess.run(pool3,{'incept/DecodeJpeg/contents:0': image.read()})

# # First, load the image again
# filename = "220px-Batian_Nelion_and_pt_Slade_in_the_foreground_Mt_Kenya.JPG"
# raw_image_data = mpimg.imread(filename)

# image = tf.placeholder("float", [None, None, 3])
# slice = tf.slice(image,[0,0,0],[-1,-1,1])

# with tf.Session() as session:
#     result = np.squeeze(result, 2)
#     plt.imshow(result)
#     plt.show()

# filenames = ['220px-Batian_Nelion_and_pt_Slade_in_the_foreground_Mt_Kenya.JPG']
# filename_queue = tf.train.string_input_producer(filenames)

# reader = tf.WholeFileReader()
# key, value = reader.read(filename_queue)

# images = tf.image.decode_jpeg(value, channels=3)

# rgb_image = tf.image.decode_png('220px-Batian_Nelion_and_pt_Slade_in_the_foreground_Mt_Kenya.JPG',  channels=3)
# image = tf.cast(rgb_image, tf.float32)
# # rgb_image_float = tf.image.convert_image_dtype(rgb_image, tf.float32)
# hsv_image = tf.image.rgb_to_hsv(image)
# Out:
# (165, 220, 1)
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py:1645: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
