# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
plt.style.use("ggplot")

# %%
result = dict()

# %% [markdown]
# #### Clean imgs (from V2)

# %%
result["acc_10_ep"] = 0.9830

# %%
result["val_acc_10_ep"] = 1.0000

# %%
result["acc_5_ep"] = 0.9572

# %%
result["val_acc_5_ep"] = 0.9915

# %%
result["time_to_learn_10_ep"] = 484+478+478+477+477+476+476+476+475+475

# %%
result["time_to_learn_5_ep"] = 480+478+478+477+477

# %%
result['loss_10_ep'] = 0.0516

# %%
result['val_loss_10_ep'] = 0.0013

# %%
result['loss_5_ep'] = 0.1231

# %%
result['val_loss_5_ep'] = 0.0270

# %%
# x = ['Nuclear', 'Hydro', 'Gas', 'Oil', 'Coal', 'Biofuel']
# energy = [5, 6, 15, 22, 24, 8]

# x_pos = [i for i, _ in enumerate(x)]

# plt.bar(x_pos, energy, color='green')
# plt.xlabel("Energy Source")
# plt.ylabel("Energy Output (GJ)")
# plt.title("Доля правильных ответов при варьировании числа эпох")

# plt.xticks(x_pos, x)
# # plt.axis('off')

# plt.show()

# %%
N = 2
acc_10_ep = (result['acc_10_ep'], result['val_acc_10_ep'])
acc_5_ep = (result['acc_5_ep'], result['val_acc_5_ep'])

ind = np.arange(N) 
width = 0.35       
plt.bar(ind, acc_10_ep, width, label='10 эпох')
plt.bar(ind + width, acc_5_ep, width,
    label='5 эпох')

# plt.ylabel('Scores')
plt.title('Доля правильных ответов при варьировании числа эпох')

plt.xticks(ind + width / 2, ('Обучающая', 'Тестовая'),fontsize=12)
plt.xlabel("Тип выборки",fontsize=13)
plt.yticks(fontsize=12)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize=12)
plt.rcParams['figure.figsize'] = [8, 5]
plt.show()

# %%
x = ['10', '5']
energy = [result['time_to_learn_10_ep']/60, result['time_to_learn_5_ep']/60]

x_pos = [i for i, _ in enumerate(x)]

plt.bar(x_pos, energy, color='green')
plt.xlabel("Количество эпох")
plt.ylabel("Время, мин")
plt.title("Время обучения при варьировании числа эпох")

plt.xticks(x_pos, x)
plt.rcParams['figure.figsize'] = [8, 5]
plt.show()

# %%
N = 2
loss_10_ep = (result['loss_10_ep'], result['val_loss_10_ep'])
loss_5_ep = (result['loss_5_ep'], result['val_loss_5_ep'])

ind = np.arange(N) 
width = 0.35       
plt.bar(ind, loss_10_ep, width, label='10 эпох')
plt.bar(ind + width, loss_5_ep, width,
    label='5 эпох')

# plt.ylabel('Scores')
plt.title('Ошибка на выборках при варьировании числа эпох')

plt.xticks(ind + width / 2, ('Обучающая', 'Тестовая'))
plt.xlabel("Тип выборки")
# plt.legend(loc='best')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.rcParams['figure.figsize'] = [8, 5]
plt.show()

# %% [markdown]
# #### Clean and dirty imgs (from V3)

# %%
result_dci = dict()

# %%
result_dci['acc_10_ep_cl'] = 0.9830

# %%
result_dci['val_acc_10_ep_cl'] = 0.9990

# %%
result_dci['acc_5_ep_cl'] = 0.9572

# %%
result_dci['val_acc_5_ep_cl'] = 0.9915

# %%
result_dci['acc_10_ep_di'] = 0.4851

# %%
result_dci['val_acc_10_ep_di'] = 0.5878

# %%
result_dci['acc_5_ep_di'] = 0.4039

# %%
result_dci['val_acc_5_ep_di'] = 0.4995

# %%
N = 4
acc_10_ep_cl = (result_dci['acc_10_ep_cl'], result_dci['val_acc_10_ep_cl'], result_dci['acc_10_ep_di'], result_dci['val_acc_10_ep_di'])
acc_5_ep_cl = (result_dci['acc_5_ep_cl'], result_dci['val_acc_5_ep_cl'], result_dci['acc_5_ep_di'], result_dci['val_acc_5_ep_di'])

# acc_10_ep_di = (result_dci['acc_10_ep_di'], result_dci['val_acc_10_ep_di'])
# acc_5_ep_di = (result_dci['acc_5_ep_di'], result_dci['val_acc_5_ep_di'])

ind = np.arange(N) 
width = 0.35       
plt.bar(ind, acc_10_ep_cl, width, label='10 эпох')
plt.bar(ind + width, acc_5_ep_cl, width,
    label='5 эпох')

# plt.bar(ind, acc_10_ep_di, width, label='10 эпох')
# plt.bar(ind + width, acc_5_ep_di, width,
#     label='5 эпох')

# plt.ylabel('Scores')
plt.title('Доля правильных ответов при различном качестве входных данных')

plt.xticks(ind + width / 2, ('Обучающая\n (искусственные)', 'Тестовая\n (искусственные)', 'Обучающая\n (фото)','Тестовая\n (фото)'))
plt.xlabel("Тип выборки")
# plt.legend(loc='best')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %% [markdown]
# #### Dirty imgs (from V4)

# %%
result_DI_DO_L = dict()

# %%
x = ['Исходная', 'Модифицированная']
energy = [7571112, 20289128]

x_pos = [i for i, _ in enumerate(x)]

plt.bar(x_pos, energy, color='green')
plt.xlabel("Вид сети")
plt.ylabel("Количество, шт")
plt.title("Количество параметров (весов входов в нейроны)")

plt.xticks(x_pos, x)
plt.rcParams['figure.figsize'] = [8, 5]
plt.show()

# %%
result_DI_DO_L['acc_7ml_weights'] = 0.4594

# %%
result_DI_DO_L['val_acc_7ml_weights'] = 0.5450

# %%
result_DI_DO_L['loss_7ml_weights'] = 1.3273

# %%
result_DI_DO_L['val_loss_7ml_weights'] = 1.1033

# %%
result_DI_DO_L['acc_20ml_weights'] = 0.4726

# %%
result_DI_DO_L['val_acc_20ml_weights'] = 0.4968

# %%
result_DI_DO_L['loss_20ml_weights'] = 1.3076

# %%
result_DI_DO_L['val_loss_20ml_weights'] = 1.2221

# %%
N = 2
acc_7ml_weights = (result_DI_DO_L['acc_7ml_weights'], result_DI_DO_L['val_acc_7ml_weights'])
acc_20ml_weights = (result_DI_DO_L['acc_20ml_weights'], result_DI_DO_L['val_acc_20ml_weights'])

ind = np.arange(N) 
width = 0.35       
plt.bar(ind, acc_7ml_weights, width, label='Исходная сеть')
plt.bar(ind + width, acc_20ml_weights, width,
    label='Модифицированная сеть')

# plt.ylabel('Scores')
plt.title('Доля правильных ответов при варьировании числа параметров')

plt.xticks(ind + width / 2, ('Обучающая', 'Тестовая'))
plt.xlabel("Тип выборки")
# plt.legend(loc='best')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.rcParams['figure.figsize'] = [8, 5]
plt.show()

# %%
N = 2
loss_7ml_weights = (result_DI_DO_L['loss_7ml_weights'], result_DI_DO_L['val_loss_7ml_weights'])
loss_20ml_weights = (result_DI_DO_L['loss_20ml_weights'], result_DI_DO_L['val_loss_20ml_weights'])

ind = np.arange(N) 
width = 0.35       
plt.bar(ind, loss_7ml_weights, width, label='Исходная сеть')
plt.bar(ind + width, loss_20ml_weights, width,
    label='Модифицированная сеть')

# plt.ylabel('Scores')
plt.title('Ошибка на выборках при варьировании числа параметров')

plt.xticks(ind + width / 2, ('Обучающая', 'Тестовая'))
plt.xlabel("Тип выборки")
# plt.legend(loc='best')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.rcParams['figure.figsize'] = [8, 5]
plt.show()

# %%
result_DI_DO_L['time_to_learn_7ml'] = 677+660+660+659+659+659+659+659+659+658

# %%
result_DI_DO_L['time_to_learn_20ml'] = 709+693+693+693+693+693+692+692+692+692

# %%
x = ['Исходная', 'Модифицированная']
energy = [result_DI_DO_L['time_to_learn_7ml']/60, result_DI_DO_L['time_to_learn_20ml']/60]

x_pos = [i for i, _ in enumerate(x)]

plt.bar(x_pos, energy, color='green')
plt.xlabel("Тип сети")
plt.ylabel("Время, мин")
plt.title("Время обучения при варьировании числа параметров")

plt.xticks(x_pos, x)
plt.rcParams['figure.figsize'] = [8, 5]
plt.show()

# %% [markdown]
# #### Different Optimizers

# %%
AdagradOptimizer = dict()

# %%
AdagradOptimizer['loss'] = 1.8885

# %%
AdagradOptimizer['acc'] = 0.3109

# %%
AdagradOptimizer['val_loss'] = 1.7972

# %%
AdagradOptimizer['val_acc'] = 0.2991

# %%
AdagradOptimizer['time_to_learn'] = 844+843+844+844+851+852+852+852+852+852

# %%
AdadeltaOptimizer = dict()

# %%
AdadeltaOptimizer['loss'] = 5.5874
AdadeltaOptimizer['acc'] = 0.0132
AdadeltaOptimizer['val_loss'] = 5.5964
AdadeltaOptimizer['val_acc'] = 0.0236
AdadeltaOptimizer['time_to_learn'] = 840+838+837+838+838+837+839+839+838+837

# %%
Adamax = dict()
Adamax['loss'] = 1.3241
Adamax['acc'] = 0.4707
Adamax['val_loss'] = 1.2856
Adamax['val_acc'] = 0.4699
Adamax['time_to_learn'] = 825+824+821+818+818+817+817+817+818+817

# %%
Nadam = dict()
Nadam['loss'] = 16.0727
Nadam['acc'] = 0.0028
Nadam['val_loss'] = 16.0750
Nadam['val_acc'] = 0.0027
Nadam['time_to_learn'] = 888+874+874+873+874+874+875+875+875+876

# %%
RMSPropOptimizer = dict()
RMSPropOptimizer['loss'] = 2.7284
RMSPropOptimizer['acc'] = 0.3337
RMSPropOptimizer['val_loss'] = 2.3471
RMSPropOptimizer['val_acc'] = 0.3492
RMSPropOptimizer['time_to_learn'] = 864+859+859+857+856+856+855+854+853+853

# %%
SGD = dict()
SGD['loss'] = 2.2283
SGD['acc'] = 0.2376
SGD['val_loss'] = 2.1842
SGD['val_acc'] = 0.2628
SGD['time_to_learn'] = 906+895+894+894+892+894+893+893+893+893

# %%
N = 6
# Adagrad_acc = (AdagradOptimizer['acc'], AdagradOptimizer['val_acc'])
# Adadelta_acc = (AdadeltaOptimizer['acc'], AdadeltaOptimizer['val_acc'])
# Adamax_acc = (Adamax['acc'], Adamax['val_acc'])
# Nadam_acc = (Nadam['acc'], Nadam['val_acc'])
# RMSprop_acc = (RMSPropOptimizer['acc'], RMSPropOptimizer['val_acc'])
# SGD_acc = (SGD['acc'], SGD['val_acc'])

optimizers_acc = (AdagradOptimizer['acc'],
                    AdadeltaOptimizer['acc'],
                    Adamax['acc'],
                    Nadam['acc'],
                    RMSPropOptimizer['acc'],
                    SGD['acc'])

optimizers_val_acc = (AdagradOptimizer['val_acc'],
                        AdadeltaOptimizer['val_acc'],
                        Adamax['val_acc'],
                        Nadam['val_acc'],
                        RMSPropOptimizer['val_acc'],
                        SGD['val_acc'])

# acc_10_ep_di = (result_dci['acc_10_ep_di'], result_dci['val_acc_10_ep_di'])
# acc_5_ep_di = (result_dci['acc_5_ep_di'], result_dci['val_acc_5_ep_di'])

ind = np.arange(N) 
width = 0.35       
plt.bar(ind, optimizers_acc, width, label='Обучающая выборка')
plt.bar(ind + width, optimizers_val_acc, width, label='Тестовая выборка')

# plt.bar(ind, acc_10_ep_di, width, label='10 эпох')
# plt.bar(ind + width, acc_5_ep_di, width,
#     label='5 эпох')

# plt.ylabel('Scores')
plt.title('Доля правильных ответов при различных оптимизаторах весов входов в нейроны')

plt.xticks(ind + width / 2, ('Adagrad', 'Adadelta', 'Adamax', 'Nadam', 'RMSProp', 'SGD'))
plt.xlabel("Оптимизатор")
# plt.legend(loc='best')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.rcParams['figure.figsize'] = [10, 7]
plt.show()

# %%
N = 6
# Adagrad_acc = (AdagradOptimizer['acc'], AdagradOptimizer['val_acc'])
# Adadelta_acc = (AdadeltaOptimizer['acc'], AdadeltaOptimizer['val_acc'])
# Adamax_acc = (Adamax['acc'], Adamax['val_acc'])
# Nadam_acc = (Nadam['acc'], Nadam['val_acc'])
# RMSprop_acc = (RMSPropOptimizer['acc'], RMSPropOptimizer['val_acc'])
# SGD_acc = (SGD['acc'], SGD['val_acc'])

optimizers_loss = (AdagradOptimizer['loss'],
                    AdadeltaOptimizer['loss'],
                    Adamax['loss'],
                    Nadam['loss'],
                    RMSPropOptimizer['loss'],
                    SGD['loss'])

optimizers_val_loss = (AdagradOptimizer['val_loss'],
                        AdadeltaOptimizer['val_loss'],
                        Adamax['val_loss'],
                        Nadam['val_loss'],
                        RMSPropOptimizer['val_loss'],
                        SGD['val_loss'])

# acc_10_ep_di = (result_dci['acc_10_ep_di'], result_dci['val_acc_10_ep_di'])
# acc_5_ep_di = (result_dci['acc_5_ep_di'], result_dci['val_acc_5_ep_di'])

ind = np.arange(N) 
width = 0.35       
plt.bar(ind, optimizers_loss, width, label='Обучающая выборка')
plt.bar(ind + width, optimizers_val_loss, width, label='Тестовая выборка')

# plt.bar(ind, acc_10_ep_di, width, label='10 эпох')
# plt.bar(ind + width, acc_5_ep_di, width,
#     label='5 эпох')

# plt.ylabel('Scores')
plt.title('Ошибка на выборках при различных оптимизаторах весов входов в нейроны')

plt.xticks(ind + width / 2, ('Adagrad', 'Adadelta', 'Adamax', 'Nadam', 'RMSProp', 'SGD'))
plt.xlabel("Оптимизатор")
# plt.legend(loc='best')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.rcParams['figure.figsize'] = [10, 8]
plt.show()

# %%
# N = 5
# men_means = (20, 35, 30, 35, 27)
# men_std = (2, 3, 4, 1, 2)

# ind = np.arange(N)  # the x locations for the groups
# width = 0.35       # the width of the bars

# fig, ax = plt.subplots()
# rects1 = ax.bar(ind, men_means, width, color='r', yerr=men_std)

# women_means = (25, 32, 34, 20, 25)
# women_std = (3, 5, 2, 3, 3)
# rects2 = ax.bar(ind + width, women_means, width, color='y', yerr=women_std)

# # add some text for labels, title and axes ticks
# ax.set_ylabel('Scores')
# ax.set_title('Scores by group and gender')
# ax.set_xticks(ind + width / 2)
# ax.set_xticklabels(('G1', 'G2', 'G3', 'G4', 'G5'))

# ax.legend((rects1[0], rects2[0]), ('Men', 'Women'))


# def autolabel(rects):
#     """
#     Attach a text label above each bar displaying its height
#     """
#     for rect in rects:
#         height = rect.get_height()
#         ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
#                 '%d' % int(height),
#                 ha='center', va='bottom')

# autolabel(rects1)
# autolabel(rects2)

# plt.show()

# %%
x = ['Adagrad', 'Adadelta', 'Adamax', 'Nadam', 'RMSProp', 'SGD']
optimizers_time = (AdagradOptimizer['time_to_learn']/60,
                    AdadeltaOptimizer['time_to_learn']/60,
                    Adamax['time_to_learn']/60,
                    Nadam['time_to_learn']/60,
                    RMSPropOptimizer['time_to_learn']/60,
                    SGD['time_to_learn']/60)

x_pos = [i for i, _ in enumerate(x)]

fig, ax = plt.subplots()

rects1 = ax.bar(x, optimizers_time, color='green')
ax.set_ylim([0, 170])
ax.set_xlabel("Оптимизатор")
ax.set_ylabel("Время, мин")
ax.set_title("Время обучения сети при различных оптимизаторах весов входов в нейроны")
ax.set_xticklabels(x)

# ax.set_xticks(x_pos, x)
# ax.rcParams['figure.figsize'] = [10, 5]

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1*height,
                '%d' % int(height),
                ha='center', va='bottom')

autolabel(rects1)
plt.rcParams['figure.figsize'] = [10, 6]
plt.show()
